# %%
#pip install matplotlib

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
len(y)
# Out:
# 7

# %%
len(x)
# Out:
# 7

# %%
Day=[1,2,3,4,5,6,7]
Temp=[50,51,52,48,47,49,46]

# %%
plt.plot(Day,Temp)
plt.show()

# %%
plt.plot(Day,Temp,color='red',linestyle='dashdot',marker='o',linewidth=2)
plt.show()

# %%
plt.xlabel('Day')
plt.ylabel('Temp')
plt.plot(Day,Temp,color='red',linestyle='dashdot',marker='o',linewidth=2,alpha=0.5)
plt.show()

# %%
plt.xlabel('Day',fontsize=15)
plt.ylabel('Temp',fontsize=15)  
plt.title('Weather info',fontsize=15)
plt.plot(Day,Temp,color='black',linestyle='dashdot',marker='o',linewidth=2)
plt.show()

# %%
#legend, Grid

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel('Day',fontsize=12)
plt.ylabel('Temp',fontsize=12)  
plt.title('Weather info',fontsize=12)
plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)
plt.show()

# %%
plt.xlabel('Day',fontsize=12)
plt.ylabel('Temp',fontsize=12)  
plt.title('Weather info',fontsize=12)
plt.plot(days,max_t,label='max')
plt.plot(days,min_t,label='min')
plt.plot(days,avg_t,label='avg')
plt.legend()
plt.show()

# %%
plt.xlabel('Day',fontsize=12)
plt.ylabel('Temp',fontsize=12)  
plt.title('Weather info',fontsize=12)
plt.plot(days,max_t,label='max')
plt.plot(days,min_t,label='min')
plt.plot(days,avg_t,label='avg')
plt.legend(loc='best',shadow=True,fontsize='small')
plt.grid()
plt.show()

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

# %%
plt.xlabel('Major Companies')
plt.ylabel('Revenue')
plt.title('Revenue Model For Top Companies')
plt.bar(company,revenue)
plt.show()

# %%
plt.xlabel('Major Companies')
plt.ylabel('Profit')
plt.title('Profit Model For Top Companies')
plt.bar(company,profit)
plt.show()

# %%
plt.xlabel('Major Companies')
plt.ylabel('Revenue And Profit')
plt.title('Revenue And Profit Model For Top Companies')
plt.bar(company,revenue,label='Revenue')
plt.bar(company,profit,label='Profit')
plt.legend(shadow=True)
plt.show()

# %%
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos,company)
plt.xlabel("Company Name")
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.bar(xpos-0.2,revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="profit")
plt.legend()
plt.show()

# %%
#Histogram

blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

# %%
plt.hist(blood_sugar)
plt.show()

# %%
#to differntiate

plt.hist(blood_sugar,rwidth=0.8)
plt.show()

# %%
#default no.of bins is 10 we change it to 3

plt.hist(blood_sugar,rwidth=0.8,bins=3)
plt.show()

# %%
plt.hist(blood_sugar,rwidth=0.8,bins=3,color='red')
plt.show()

# %%
plt.hist(blood_sugar,bins=[80,100,125,150] ,rwidth=0.8) # by default number of bins is set to 10
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
#multiple samples

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([blood_sugar_men,blood_sugar_women],label=['Men','Women'])
plt.legend()
plt.show()

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150],rwidth=0.8,color=['red','black'],label=['men','women'])
plt.legend()
plt.show()

# %%
np.random.seed(10)
data=np.random.normal(100,20,200)

# %%
data
# Out:
# array([126.63173008, 114.30557949,  69.09199416,  99.832323  ,
#        112.42671948,  85.59828879, 105.31023171, 102.17097051,
#        100.08582862,  96.50799579, 108.6605238 , 124.06074748,
#         80.69868659, 120.56548156, 104.5726026 , 108.90275226,
#         77.26795576, 102.70273757, 129.69074004,  78.40390228,
#         60.44543439,  65.13255408, 105.32140328, 147.69934661,
#        122.47382507, 133.45244427, 101.98298432, 127.95992754,
#         94.57504024, 112.2640837 ,  94.65365623,  89.01381972,
#        102.65416592,  90.4771597 , 126.16946162, 103.90026558,
#        108.00419977,  93.24735326, 125.12944528,  85.36060996,
#        113.20463102,  92.98256217,  81.2113328 ,  90.21325566,
#         83.90817715,  95.74604723,  93.21719508, 106.24339873,
#        111.30305339,  97.05159485,  99.48189326, 105.78188408,
#         89.20241857, 114.1632004 , 116.84449477, 104.07161595,
#        147.8940733 , 118.34917875,  97.75455058,  92.75639106,
# ...

# %%
plt.hist(data)
# Out:
# (array([ 1.,  6.,  9., 14., 43., 45., 40., 26.,  8.,  8.]),
#  array([ 40.40806458,  51.30256023,  62.19705589,  73.09155154,
#          83.9860472 ,  94.88054285, 105.77503851, 116.66953416,
#         127.56402982, 138.45852547, 149.35302113]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,rwidth=0.8)
plt.show()

# %%
#boxplot

plt.boxplot(data)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.boxplot(data)
plt.show()

# %%
np.random.seed(10)
data1=np.random.normal(100,10,200)
data2=np.random.normal(90,20,200)
data3=np.random.normal(80,30,200)
data4=np.random.normal(70,40,200)

data=(data1,data2,data3,data4)
plt.figure(figsize=(10,5))

plt.boxplot(data)
plt.show()

# %%
np.random.seed(10)
data1=np.random.normal(100,10,200)
data2=np.random.normal(90,20,200)
data3=np.random.normal(80,30,200)
data4=np.random.normal(70,40,200)

data=(data1,data2,data3,data4)
plt.figure(figsize=(10,5))

plt.boxplot(data,vert=False,patch_artist=True)
plt.show()

# %%
#pie chart
# Draw pie chart to track down home expenses
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

plt.pie(exp_vals,labels=exp_labels)
plt.show()

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

plt.figure(figsize=(10,5))
plt.axis('equal')
plt.pie(exp_vals,labels=exp_labels,radius=1.2,autopct='%0.2f%%',shadow=True,explode=[0.1,0,0.2,0,0],startangle=90)
plt.legend()
#plt.show()
plt.savefig('piechart_new.jpg')
